# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Bước 1: Load ảnh 
# Bước 2: Khởi tạo PCA
# Bước 3: ÁP dụng PCA để giảm số chiều cho từng kênh R, G, B độc lập
# Bước 4: Khôi phục ảnh trên từng kênh màu R, G, B độc lập
# Gợi ý: dùng inverse_transform
# Bước 5: Ráp 3 kênh màu lại thành 1 iamge và show

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/drive/MyDrive/Python-máy-học/dog.jpeg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x793 at 0x7FE60DB32150>

# %%
blue,green,red = cv2.split(img)

# %%
from sklearn.decomposition import PCA

pca = PCA(20)
 
red_transformed = pca.fit_transform(red)
red_inverted = pca.inverse_transform(red_transformed)
 
green_transformed = pca.fit_transform(green)
green_inverted = pca.inverse_transform(green_transformed)
 
blue_transformed = pca.fit_transform(blue)
blue_inverted = pca.inverse_transform(blue_transformed)

# %%
img_compressed = (np.dstack((blue_inverted, green_inverted, red_inverted))).astype(np.uint8)
cv2_imshow(img_compressed)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x793 at 0x7FE60D91E4D0>

# %%
image_merged = cv2.merge((blue_inverted, green_inverted, red_inverted))
cv2_imshow(image_merged)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x793 at 0x7FE60D997590>
